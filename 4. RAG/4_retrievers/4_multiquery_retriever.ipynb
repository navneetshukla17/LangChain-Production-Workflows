# %%
# necessary imports
from langchain_huggingface import HuggingFaceEndpoint, HuggingFaceEmbeddings, ChatHuggingFace
from langchain_core.documents import Document
from langchain_community.vectorstores import Pinecone
from dotenv import load_dotenv

# load huggingface api key
load_dotenv()
# Out:
# True

# %%
# sample documents
docs = [
    Document(page_content="Regular walking boosts heart health and can reduce symptoms of depression.", metadata={"source": "H1"}),
    Document(page_content="Consuming leafy greens and fruits helps detox the body and improve longevity.", metadata={"source": "H2"}),
    Document(page_content="Deep sleep is crucial for cellular repair and emotional regulation.", metadata={"source": "H3"}),
    Document(page_content="Mindfulness and controlled breathing lower cortisol and improve mental clarity.", metadata={"source": "H4"}),
    Document(page_content="Drinking sufficient water throughout the day helps maintain metabolism and energy.", metadata={"source": "H5"}),
    Document(page_content="The solar energy system in modern homes helps balance electricity demand.", metadata={"source": "I1"}),
    Document(page_content="Python balances readability with power, making it a popular system design language.", metadata={"source": "I2"}),
    Document(page_content="Photosynthesis enables plants to produce energy by converting sunlight.", metadata={"source": "I3"}),
    Document(page_content="The 2022 FIFA World Cup was held in Qatar and drew global energy and excitement.", metadata={"source": "I4"}),
    Document(page_content="Black holes bend spacetime and store immense gravitational energy.", metadata={"source": "I5"}),
]

# %%
# embedding model
embedding_model = HuggingFaceEmbeddings(model="sentence-transformers/all-MiniLM-L6-v2")

# LLM config
llm = HuggingFaceEndpoint(
    repo_id="google/gemma-2-2b-it",
    task="text-generation"
)

# model config
model = ChatHuggingFace(llm=llm)

# %%
# vector store
vector_store = Pinecone.from_documents(
    documents=docs,
    embedding=embedding_model
)
# Out:
# ---------------------------------------------------------------------------
# PineconeConfigurationError                Traceback (most recent call last)
# Cell In[41], line 2
#       1 # vector store
# ----> 2 vector_store = Pinecone.from_documents(
#       3     documents=docs,
#       4     embedding=embedding_model
#       5 )
#
# File ~/GENAI/venv/lib/python3.13/site-packages/langchain_core/vectorstores/base.py:813, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     810     if any(ids):
#     811         kwargs["ids"] = ids
# --> 813 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/GENAI/venv/lib/python3.13/site-packages/langchain_community/vectorstores/pinecone.py:432, in Pinecone.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, **kwargs)
#     389 @classmethod
#     390 def from_texts(
#     391     cls,
#    (...)    403     **kwargs: Any,
#     404 ) -> Pinecone:
#     405     """
#     406     DEPRECATED: use langchain_pinecone.PineconeVectorStore.from_texts instead:
#     407     Construct Pinecone wrapper from raw documents.
#    (...)    430             )
#     431     """
# --> 432     pinecone_index = cls.get_pinecone_index(index_name, pool_threads)
#     433     pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
#     435     pinecone.add_texts(
#     436         texts,
#     437         metadatas=metadatas,
#    (...)    442         **(upsert_kwargs or {}),
#     443     )
#
# File ~/GENAI/venv/lib/python3.13/site-packages/langchain_community/vectorstores/pinecone.py:362, in Pinecone.get_pinecone_index(cls, index_name, pool_threads)
#     359 pinecone = _import_pinecone()
#     361 if _is_pinecone_v3():
# --> 362     pinecone_instance = pinecone.Pinecone(
#     363         api_key=os.environ.get("PINECONE_API_KEY"), pool_threads=pool_threads
#     364     )
#     365     indexes = pinecone_instance.list_indexes()
#     366     index_names = [i.name for i in indexes.index_list["indexes"]]
#
# File ~/GENAI/venv/lib/python3.13/site-packages/pinecone/pinecone.py:228, in Pinecone.__init__(self, api_key, host, proxy_url, proxy_headers, ssl_ca_certs, ssl_verify, additional_headers, pool_threads, **kwargs)
#     223     if deprecated_kwarg in kwargs:
#     224         raise NotImplementedError(
#     225             f"Passing {deprecated_kwarg} is no longer supported. Please pass individual settings such as proxy_url, proxy_headers, ssl_ca_certs, and ssl_verify directly to the Pinecone constructor as keyword arguments. See the README at {docslinks['README']} for examples."
#     226         )
# --> 228 self._config = PineconeConfig.build(
#     229     api_key=api_key,
#     230     host=host,
#     231     additional_headers=additional_headers,
#     232     proxy_url=proxy_url,
#     233     proxy_headers=proxy_headers,
#     234     ssl_ca_certs=ssl_ca_certs,
#     235     ssl_verify=ssl_verify,
#     236     **kwargs,
#     237 )
#     238 """ :meta private: """
#     240 self._openapi_config = ConfigBuilder.build_openapi_config(self._config, **kwargs)
#
# File ~/GENAI/venv/lib/python3.13/site-packages/pinecone/config/pinecone_config.py:34, in PineconeConfig.build(api_key, host, additional_headers, **kwargs)
#      31     except Exception as e:
#      32         logger.warn(f"Ignoring PINECONE_ADDITIONAL_HEADERS: {e}")
# ---> 34 return ConfigBuilder.build(
#      35     api_key=api_key, host=host, additional_headers=additional_headers, **kwargs
#      36 )
#
# File ~/GENAI/venv/lib/python3.13/site-packages/pinecone/config/config.py:69, in ConfigBuilder.build(api_key, host, proxy_url, proxy_headers, ssl_ca_certs, ssl_verify, additional_headers, **kwargs)
#      66 source_tag = kwargs.pop("source_tag", None)
#      68 if not api_key:
# ---> 69     raise PineconeConfigurationError(
#      70         "You haven't specified an API key. Please either set the PINECONE_API_KEY environment variable or pass the 'api_key' keyword argument to the Pinecone client constructor."
#      71     )
#      72 if not host:
#      73     raise PineconeConfigurationError("You haven't specified a host.")
#
# PineconeConfigurationError: You haven't specified an API key. Please either set the PINECONE_API_KEY environment variable or pass the 'api_key' keyword argument to the Pinecone client constructor.

# %%
# retriever

# %%
# final output
